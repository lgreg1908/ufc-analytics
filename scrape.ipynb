# %%
import os
from typing import List
from pydantic import BaseModel
from src.scrape.scrapers import (
    EventsScraper, 
    FightersScraper, 
    ResultsScraper, 
    RoundsScraper)
from src.scrape.utils import (
    load_yaml, 
    save_models_to_json, 
    convert_models_to_dicts, 
    get_event_urls, 
    get_fight_urls, 
    get_fighter_urls)
from src.logger import setup_logger

logger = setup_logger()

# %%
def scrape_events(config: dict) -> List[BaseModel]:
    """Scrape events using the provided configuration."""
    event_scraper = EventsScraper()
    events = event_scraper.scrape_events([config['event_urls']['all']])
    return events

def extract_event_urls(events: List[BaseModel]) -> List[str]:
    """Extract event URLs from the list of event models."""
    return get_event_urls(events_data=convert_models_to_dicts(models=events))

def scrape_results(event_urls: List[str]) -> List[BaseModel]:
    """Scrape results using event URLs."""
    result_scraper = ResultsScraper()
    results = result_scraper.scrape_results(event_urls=event_urls)
    return results

def extract_fight_urls(results: List[BaseModel]) -> List[str]:
    """Extract fight URLs from the results models."""
    return get_fight_urls(results_data=convert_models_to_dicts(models=results))

def scrape_rounds(fight_urls: List[str]) -> List[BaseModel]:
    """Scrape rounds using fight URLs."""
    rounds_scraper = RoundsScraper()
    rounds = rounds_scraper.scrape_rounds(fight_urls=fight_urls)
    return rounds

def extract_fighter_urls(results: List[BaseModel]) -> List[str]:
    """Extract fighter URLs from the results models."""
    return get_fighter_urls(results_data=convert_models_to_dicts(models=results))

def scrape_fighters(fighter_urls: List[str]) -> List[BaseModel]:
    """Scrape fighters using fighter URLs."""
    fighters_scraper = FightersScraper()
    fighters = fighters_scraper.scrape_fighters(fighter_urls=fighter_urls)
    return fighters

# %%
# =============================================================================
# Pipeline Runner
# =============================================================================

def run_pipeline(config: dict, root_dir: str) -> None:
    """
    Run the complete scraping pipeline and save the outputs to JSON files.
    
    The pipeline:
      1. Scrapes events and extracts event URLs.
      2. Scrapes results based on event URLs and extracts fight URLs.
      3. Scrapes rounds using fight URLs.
      4. Extracts fighter URLs from results and scrapes fighters.
      5. Saves all the scraped models to their respective JSON files.
    """
    # Step 1: Events
    events = scrape_events(config)
    event_urls = extract_event_urls(events)
    
    # Step 2: Results
    results = scrape_results(event_urls)
    fight_urls = extract_fight_urls(results)
    
    # Step 3: Rounds
    rounds = scrape_rounds(fight_urls)
    
    # Step 4: Fighters
    fighter_urls = extract_fighter_urls(results)
    fighters = scrape_fighters(fighter_urls)
    
    # Step 5: Save the models
    models_to_save = {
        'events': events,
        'fighters': fighters,
        'rounds': rounds,
        'results': results,
    }
    
    for key, models in models_to_save.items():
        filepath = os.path.join(root_dir, config['output_files']['raw'][key])
        save_models_to_json(models=models, filepath=filepath)

# %%
def main():
    root_dir = os.path.abspath('.')
    config_path = os.path.join(root_dir, 'config', 'config.yaml')
    config = load_yaml(config_path)
    run_pipeline(config, root_dir)

# %%
main()
# Out:
# 2025-02-11 17:08:11,099 - src.scrape.scrapers - INFO - Starting concurrent scraping of events.
# 2025-02-11 17:08:12,412 - src.scrape.scrapers - INFO - Completed scraping events.
# 2025-02-11 17:08:12,418 - src.scrape.utils - INFO - Successfully extracted 719 event URLs.
# 2025-02-11 17:08:12,420 - src.scrape.scrapers - INFO - Starting concurrent scraping of fight results.
# 2025-02-11 17:09:13,376 - src.scrape.scrapers - INFO - Completed scraping fight results.
# 2025-02-11 17:09:13,425 - src.scrape.utils - INFO - Successfully extracted 8024 unique fight URLs.
# 2025-02-11 17:09:13,429 - src.scrape.scrapers - INFO - Starting concurrent scraping of rounds data.
# 2025-02-11 17:09:23,918 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:09:23,920 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/a1db4c917777aa79
# 2025-02-11 17:10:00,622 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:10:00,687 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/4bce0ce561a65288
# 2025-02-11 17:11:03,606 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:11:03,683 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/c413b0abc04358c3
# 2025-02-11 17:11:41,274 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:11:41,277 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/635fbf57001897c7
# 2025-02-11 17:12:58,544 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:12:58,548 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/8b258bbb37f74a66
# 2025-02-11 17:13:04,488 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:13:04,491 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/7ffcc3a72e082ace
# 2025-02-11 17:14:44,445 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:14:44,483 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/6449a1a9a69a830c
# 2025-02-11 17:16:26,552 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:16:26,555 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/f59b1215176636f6
# 2025-02-11 17:16:34,019 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:16:34,023 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/b80872821bc4f6ba
# 2025-02-11 17:16:58,268 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:16:58,271 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/4b334c9727eee450
# 2025-02-11 17:19:47,105 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:19:47,109 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/b80e6a799c95d499
# 2025-02-11 17:20:02,635 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:20:02,638 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/b297c3e938e1005e
# 2025-02-11 17:20:25,583 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:20:25,591 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/3badedeb2c5533f4
# 2025-02-11 17:20:30,097 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:20:30,099 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/8e03db41687d9132
# 2025-02-11 17:20:55,792 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:20:55,854 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/2f449bd58b3d9a99
# 2025-02-11 17:22:09,192 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:22:09,197 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/d93c8c77e1091a16
# 2025-02-11 17:22:12,230 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:22:12,233 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/565ecefd8a37ad7e
# 2025-02-11 17:22:13,727 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:22:13,731 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/e4fe950846b51bdf
# 2025-02-11 17:23:24,606 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:23:24,610 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/77bf1e37929b0d59
# 2025-02-11 17:24:07,474 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:24:07,478 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/a5c90086fb65f58e
# 2025-02-11 17:24:13,018 - src.scrape.parsers.rounds - WARNING - No round details found for this fight.
# 2025-02-11 17:24:13,021 - src.scrape.scrapers - WARNING - No data parsed from http://ufcstats.com/fight-details/5701dbbbfa4f8313
# 2025-02-11 17:24:21,955 - src.scrape.scrapers - INFO - Completed scraping rounds data.
# 2025-02-11 17:24:22,025 - src.scrape.utils - INFO - Successfully extracted 2564 unique fighter URLs.
# 2025-02-11 17:24:22,030 - src.scrape.scrapers - INFO - Starting concurrent scraping of fighter details.
# 2025-02-11 17:27:39,737 - src.scrape.scrapers - INFO - Completed scraping fighter details.
